# %%
import json
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
import pickle
import os

lemmatizer = WordNetLemmatizer()

words = []
classes = []
documents = []
ignore_words = ['?', '!']

# Sesuaikan jalur file data.json dengan lokasi sebenarnya
data_file = open('C:/Users/chady/Downloads/chatbo/model/data.json').read()
intents = json.loads(data_file)

for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # add to documents
        documents.append((w, intent['tag']))
        # add to classes
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Buat direktori 'model' jika belum ada
if not os.path.exists('C:/Users/chady/Downloads/chatbo/model'):
    os.makedirs('C:/Users/chady/Downloads/chatbo/model')

pickle.dump(words, open('C:/Users/chady/Downloads/chatbo/model/texts.pkl', 'wb'))
pickle.dump(classes, open('C:/Users/chady/Downloads/chatbo/model/labels.pkl', 'wb'))

training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)

# Extract features and labels
train_x = []
train_y = []
for feature, label in training:
    train_x.append(feature)
    train_y.append(label)

train_x = np.array(train_x)
train_y = np.array(train_y)

print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fit the model
hist = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('C:/Users/chady/Downloads/chatbo/model/models.h5', hist)

print("model created")
# Out:
# 81 documents
# 34 classes ['beasiswa', 'biaya_kuliah', 'biaya_kuliah_d3', 'biaya_kuliah_d4', 'fasilitas_kampus', 'greeting1', 'greeting2', 'greeting3', 'greeting4', 'greeting5', 'greeting6', 'greeting_malam', 'info_kampus', 'jadwal_kuliah', 'jurusan', 'kegiatan_kampus', 'kontak', 'lokasi', 'misi', 'noanswer', 'pendaftaran', 'perpustakaan', 'prodi_administrasi_bisnis', 'prodi_akuntansi', 'prodi_pariwisata', 'prodi_teknik_elektro', 'prodi_teknik_mesin', 'prodi_teknik_sipil', 'prodi_teknologi_informasi', 'program_studi', 'tidak', 'visi', 'visi_dan_misi', 'ya']
# 70 unique lemmatized words ['ab', 'administrasi', 'aktivitas', 'akuntansi', 'alamat', 'beasiswa', 'biaya', 'bisnis', 'cara', 'contact', 'd3', 'd4', 'daftar', 'dan', 'elektro', 'event', 'fasilitas', 'ga', 'hai', 'halo', 'harga', 'hello', 'hubungi', 'info', 'informasi', 'iya', 'jadwal', 'jrsn', 'jurusan', 'kampus', 'kegiatan', 'kontak', 'kuliah', 'lembaga', 'lokasi', 'malam', 'malem', 'mendaftar', 'mesin', 'misi', 'ngga', 'nggak', 'no', 'pagi', 'pariwisata', 'pendaftaran', 'pendidikan', 'perpus', 'perpustakaan', 'pnb', 'prodi', 'program', 'prose', 'scholarship', 'selamat', 'siang', 'sipil', 'sore', 'studi', 'teknik', 'teknologi', 'tentang', 'ti', 'tidak', 'uang', 'ukt', 'visi', 'ya', 'yap', 'yes']
# Training data created
# Epoch 1/200
# 17/17 [==============================] - 1s 3ms/step - loss: 3.5470 - accuracy: 0.0494
# Epoch 2/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.5015 - accuracy: 0.0247
# Epoch 3/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.4737 - accuracy: 0.0247
# Epoch 4/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.3987 - accuracy: 0.0494
# Epoch 5/200
# 17/17 [==============================] - 0s 3ms/step - loss: 3.3756 - accuracy: 0.0741
# Epoch 6/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.3320 - accuracy: 0.1111
# Epoch 7/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.2760 - accuracy: 0.0988
# Epoch 8/200
# 17/17 [==============================] - 0s 5ms/step - loss: 3.1952 - accuracy: 0.1111
# Epoch 9/200
# 17/17 [==============================] - 0s 5ms/step - loss: 3.2728 - accuracy: 0.0617
# Epoch 10/200
# 17/17 [==============================] - 0s 4ms/step - loss: 3.0977 - accuracy: 0.1728
# Epoch 11/200
# 17/17 [==============================] - 0s 3ms/step - loss: 3.0404 - accuracy: 0.1605
# Epoch 12/200
# 17/17 [==============================] - 0s 3ms/step - loss: 2.9217 - accuracy: 0.2593
# Epoch 13/200
# 17/17 [==============================] - 0s 5ms/step - loss: 2.7940 - accuracy: 0.2593
# Epoch 14/200
# 17/17 [==============================] - 0s 5ms/step - loss: 2.7432 - accuracy: 0.2716
# Epoch 15/200
# 17/17 [==============================] - 0s 4ms/step - loss: 2.6864 - accuracy: 0.3086
# Epoch 16/200
# 17/17 [==============================] - 0s 3ms/step - loss: 2.5014 - accuracy: 0.3951
# Epoch 17/200
# 17/17 [==============================] - 0s 3ms/step - loss: 2.5293 - accuracy: 0.2840
# Epoch 18/200
# 17/17 [==============================] - 0s 2ms/step - loss: 2.3599 - accuracy: 0.3951
# Epoch 19/200
# 17/17 [==============================] - 0s 3ms/step - loss: 2.2901 - accuracy: 0.3580
# Epoch 20/200
# 17/17 [==============================] - 0s 2ms/step - loss: 2.3601 - accuracy: 0.3210
# Epoch 21/200
# 17/17 [==============================] - 0s 2ms/step - loss: 2.1923 - accuracy: 0.4198
# Epoch 22/200
# 17/17 [==============================] - 0s 2ms/step - loss: 2.2154 - accuracy: 0.3704
# Epoch 23/200
# 17/17 [==============================] - 0s 3ms/step - loss: 2.0155 - accuracy: 0.4198
# Epoch 24/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.8948 - accuracy: 0.4815
# Epoch 25/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.9255 - accuracy: 0.4691
# Epoch 26/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.9290 - accuracy: 0.4444
# Epoch 27/200
# 17/17 [==============================] - 0s 4ms/step - loss: 1.8229 - accuracy: 0.5062
# Epoch 28/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5540 - accuracy: 0.5802
# Epoch 29/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.6808 - accuracy: 0.5309
# Epoch 30/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.5005 - accuracy: 0.5802
# Epoch 31/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.4793 - accuracy: 0.5926
# Epoch 32/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3534 - accuracy: 0.6667
# Epoch 33/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.5491 - accuracy: 0.5432
# Epoch 34/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.5281 - accuracy: 0.5802
# Epoch 35/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3047 - accuracy: 0.6420
# Epoch 36/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.3150 - accuracy: 0.6543
# Epoch 37/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.1814 - accuracy: 0.6790
# Epoch 38/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.2245 - accuracy: 0.6914
# Epoch 39/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.0741 - accuracy: 0.6543
# Epoch 40/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3531 - accuracy: 0.5926
# Epoch 41/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.0357 - accuracy: 0.6914
# Epoch 42/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.9134 - accuracy: 0.7778
# Epoch 43/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.0455 - accuracy: 0.6420
# Epoch 44/200
# 17/17 [==============================] - 0s 3ms/step - loss: 1.3342 - accuracy: 0.6296
# Epoch 45/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7443 - accuracy: 0.8148
# Epoch 46/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.9593 - accuracy: 0.7160
# Epoch 47/200
# 17/17 [==============================] - 0s 2ms/step - loss: 1.1392 - accuracy: 0.7160
# Epoch 48/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.8592 - accuracy: 0.7531
# Epoch 49/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8499 - accuracy: 0.7654
# Epoch 50/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.9073 - accuracy: 0.7531
# Epoch 51/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.8431 - accuracy: 0.7654
# Epoch 52/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7396 - accuracy: 0.8519
# Epoch 53/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7153 - accuracy: 0.8148
# Epoch 54/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.7427 - accuracy: 0.7654
# Epoch 55/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7702 - accuracy: 0.7407
# Epoch 56/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.7177 - accuracy: 0.8272
# Epoch 57/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5376 - accuracy: 0.8765
# Epoch 58/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.8025
# Epoch 59/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.8272
# Epoch 60/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5754 - accuracy: 0.8642
# Epoch 61/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5513 - accuracy: 0.8765
# Epoch 62/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5202 - accuracy: 0.8148
# Epoch 63/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.8025
# Epoch 64/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.6244 - accuracy: 0.8025
# Epoch 65/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4582 - accuracy: 0.8889
# Epoch 66/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.8642
# Epoch 67/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4651 - accuracy: 0.8765
# Epoch 68/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5003 - accuracy: 0.8395
# Epoch 69/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3481 - accuracy: 0.9012
# Epoch 70/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.9012
# Epoch 71/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5686 - accuracy: 0.8642
# Epoch 72/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3322 - accuracy: 0.9506
# Epoch 73/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.5142 - accuracy: 0.8025
# Epoch 74/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.9012
# Epoch 75/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.8889
# Epoch 76/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4963 - accuracy: 0.8025
# Epoch 77/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.8765
# Epoch 78/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4725 - accuracy: 0.8395
# Epoch 79/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5111 - accuracy: 0.8519
# Epoch 80/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.5162 - accuracy: 0.7901
# Epoch 81/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4480 - accuracy: 0.8395
# Epoch 82/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3535 - accuracy: 0.9012
# Epoch 83/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.8642
# Epoch 84/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3295 - accuracy: 0.9136
# Epoch 85/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4175 - accuracy: 0.8395
# Epoch 86/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3891 - accuracy: 0.8765
# Epoch 87/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.9506
# Epoch 88/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.8765
# Epoch 89/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2815 - accuracy: 0.9506
# Epoch 90/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2726 - accuracy: 0.9383
# Epoch 91/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4273 - accuracy: 0.9012
# Epoch 92/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.8889
# Epoch 93/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3191 - accuracy: 0.9259
# Epoch 94/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.8519
# Epoch 95/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.8642
# Epoch 96/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3291 - accuracy: 0.9012
# Epoch 97/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3226 - accuracy: 0.9136
# Epoch 98/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2931 - accuracy: 0.9259
# Epoch 99/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1982 - accuracy: 0.9630
# Epoch 100/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3332 - accuracy: 0.8889
# Epoch 101/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3455 - accuracy: 0.8765
# Epoch 102/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3116 - accuracy: 0.9136
# Epoch 103/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3204 - accuracy: 0.9012
# Epoch 104/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3877 - accuracy: 0.9136
# Epoch 105/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2583 - accuracy: 0.8889
# Epoch 106/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2562 - accuracy: 0.9259
# Epoch 107/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2801 - accuracy: 0.9012
# Epoch 108/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2253 - accuracy: 0.9630
# Epoch 109/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2535 - accuracy: 0.9259
# Epoch 110/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3197 - accuracy: 0.9259
# Epoch 111/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2383 - accuracy: 0.9136
# Epoch 112/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2640 - accuracy: 0.9136
# Epoch 113/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3156 - accuracy: 0.8765
# Epoch 114/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3182 - accuracy: 0.9012
# Epoch 115/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.9383
# Epoch 116/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.3457 - accuracy: 0.9012
# Epoch 117/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2094 - accuracy: 0.9630
# Epoch 118/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2356 - accuracy: 0.9630
# Epoch 119/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2449 - accuracy: 0.9630
# Epoch 120/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2212 - accuracy: 0.9259
# Epoch 121/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.9383
# Epoch 122/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1934 - accuracy: 0.9753
# Epoch 123/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.9753
# Epoch 124/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2586 - accuracy: 0.9012
# Epoch 125/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2051 - accuracy: 0.9383
# Epoch 126/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1946 - accuracy: 0.9383
# Epoch 127/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1607 - accuracy: 0.9877
# Epoch 128/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2451 - accuracy: 0.9136
# Epoch 129/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2593 - accuracy: 0.9012
# Epoch 130/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1364 - accuracy: 0.9753
# Epoch 131/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 0.9753
# Epoch 132/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1822 - accuracy: 0.9383
# Epoch 133/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2738 - accuracy: 0.9259
# Epoch 134/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9877
# Epoch 135/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2371 - accuracy: 0.9136
# Epoch 136/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8765
# Epoch 137/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2971 - accuracy: 0.9259
# Epoch 138/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.2085 - accuracy: 0.9506
# Epoch 139/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9630
# Epoch 140/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3135 - accuracy: 0.9383
# Epoch 141/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2123 - accuracy: 0.9630
# Epoch 142/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1751 - accuracy: 0.9383
# Epoch 143/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1634 - accuracy: 0.9630
# Epoch 144/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1942 - accuracy: 0.9506
# Epoch 145/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1978 - accuracy: 0.9506
# Epoch 146/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1483 - accuracy: 0.9753
# Epoch 147/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1520 - accuracy: 0.9877
# Epoch 148/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.9630
# Epoch 149/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2270 - accuracy: 0.9506
# Epoch 150/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1880 - accuracy: 0.9506
# Epoch 151/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1868 - accuracy: 0.9259
# Epoch 152/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3013 - accuracy: 0.9259
# Epoch 153/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9753
# Epoch 154/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2538 - accuracy: 0.9383
# Epoch 155/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9259
# Epoch 156/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2085 - accuracy: 0.9136
# Epoch 157/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2088 - accuracy: 0.9506
# Epoch 158/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3199 - accuracy: 0.9259
# Epoch 159/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2327 - accuracy: 0.9383
# Epoch 160/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1265 - accuracy: 0.9630
# Epoch 161/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9753
# Epoch 162/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1554 - accuracy: 0.9630
# Epoch 163/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2236 - accuracy: 0.9136
# Epoch 164/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9630
# Epoch 165/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1293 - accuracy: 0.9753
# Epoch 166/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1984 - accuracy: 0.9506
# Epoch 167/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1771 - accuracy: 0.9259
# Epoch 168/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1996 - accuracy: 0.9383
# Epoch 169/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2360 - accuracy: 0.9012
# Epoch 170/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1812 - accuracy: 0.9136
# Epoch 171/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9506
# Epoch 172/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9506
# Epoch 173/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1222 - accuracy: 0.9753
# Epoch 174/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.8889
# Epoch 175/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9630
# Epoch 176/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3779 - accuracy: 0.8642
# Epoch 177/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2174 - accuracy: 0.9383
# Epoch 178/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1893 - accuracy: 0.9383
# Epoch 179/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.9753
# Epoch 180/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2600 - accuracy: 0.9136
# Epoch 181/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.9136
# Epoch 182/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1484 - accuracy: 0.9136
# Epoch 183/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0992 - accuracy: 0.9753
# Epoch 184/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9383
# Epoch 185/200
# 17/17 [==============================] - 0s 2ms/step - loss: 0.3155 - accuracy: 0.8765
# Epoch 186/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0883 - accuracy: 0.9877
# Epoch 187/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.3318 - accuracy: 0.9259
# Epoch 188/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1877 - accuracy: 0.9630
# Epoch 189/200
# 17/17 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9630
# Epoch 190/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1198 - accuracy: 0.9753
# Epoch 191/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1537 - accuracy: 0.9753
# Epoch 192/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1225 - accuracy: 0.9630
# Epoch 193/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2305 - accuracy: 0.9383
# Epoch 194/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.9630
# Epoch 195/200
# 17/17 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.9136
# Epoch 196/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1701 - accuracy: 0.9630
# Epoch 197/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2321 - accuracy: 0.9383
# Epoch 198/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0560 - accuracy: 0.9877
# Epoch 199/200
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1420 - accuracy: 0.9630
# Epoch 200/200
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 0.9877
# model created
